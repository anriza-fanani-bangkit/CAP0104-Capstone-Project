# %%
import requests

# %%
url = "http://34.101.176.23:5000/predict"
files = {'files': open('test_processed.csv', 'rb')}

# %%
r = requests.post(url, files=files)

# %%
print(r.json())
# Out:
# {'prediction': {'0': 9.3272256851, '1': 12.0199861526, '2': 3.4538636208, '3': 6.9834990501, '4': 17.6420497894, '5': 11.6674156189, '6': 4.8411684036, '7': 64.9682312012, '8': 13.3124504089, '9': 6.5795750618, '10': 7.3162221909, '11': 21.1235771179, '12': 4.4586677551, '13': 5.6633749008, '14': 9.0510120392, '15': 15.2767562866, '16': 4.8009982109, '17': 8.4342002869, '18': 3.9036669731, '19': 4.7251567841, '20': 8.0282526016, '21': 7.4402976036, '22': 6.8647933006, '23': 8.017033577, '24': 21.9880542755, '25': 6.2621750832, '26': 53.1647605896, '27': 30.7474861145, '28': 3.5354325771, '29': 20.10131073, '30': 9.5075483322, '31': 4.3621892929, '32': 4.0684394836, '33': 7.3708262444, '34': 5.3008852005, '35': 6.5038976669, '36': 3.6766901016, '37': 4.0978345871, '38': 6.5721688271, '39': 3.3616087437, '40': 23.9503936768, '41': 9.7908601761, '42': 24.5306110382, '43': 10.8427772522, '44': 3.827401638, '45': 10.5277061462, '46': 6.2562160492, '47': 5.6811337471, '48': 5.163749218, '4
# ...
